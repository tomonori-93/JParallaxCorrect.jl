# %%
include("./JParallaxCorrect.jl")
using .JParallaxCorrect

ncol = 100  # column number of pixel
nlin = 100  # line number of pixel
lonmin = 150.0  # western boundary of the satellite image
latmin = 30.0  # southern boundary of the satellite image
hmax_cld = 15000.0  # the maximum height of a virtual cloud

tbb = Matrix{Float64}(undef,ncol,nlin)
lon = (Vector(1:ncol) .- 1) .* 0.02
lat = (Vector(1:nlin) .- 1) .* 0.02

# %%
using Plots

heatmap()
